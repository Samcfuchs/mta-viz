# %% [markdown]
# # Python Data Processing
#
# Functionally: the MTA doesn't like us sending requests to their API from client
# devices. The server needs to make the requests and buffer them for the client.
# This means doing protobuf processing in python (unless there's a way to pass the
# unmodified protobuf files to the already working TypeScript processor). It
# remains to be seen just how much of the data processing should happen in python
# and how much should stay on client-side. I'm going to end up making my own API.
#
# So what data would we like to receive from a rendering standpoint? Assuming a 30s lag time...
#
# A list of **Trains**:
#
# **Train**:
# - tripID : string
# - nextStop : { stopTime: number, stopID: string }
# - prevStop : { stopTime: number, stopID: string }
# - route_id : string
#
# This is made a little easier than it would have been on the client side, because
# the server can be *always running* and have a backlog of data. We can buffer the
# data through a database. One python script feeds the database, and the server
# (who never really uses the realtime URLs) just pulls trains from the database to
# serve to clients.

# %%
import requests
from google.transit import gtfs_realtime_pb2
import sqlite3
import time

# %%
url = "https://api-endpoint.mta.info/Dataservice/mtagtfsfeeds/nyct%2Fgtfs-l"

feed = gtfs_realtime_pb2.FeedMessage()
response = requests.get(url)
feed.ParseFromString(response.content)
print("Current unix time:", int(time.time()))
# Out:
# Current unix time: 1748444965

# %% [markdown]
# Combine fields from trip_updates and vehicles. Data for each train is split across these two objects--we combine them into one so we can always index by the route id (which is unique).

# %%
from collections import defaultdict
updates = defaultdict(lambda: {'trip':{},'trip_update':{},'vehicle':{}})
n = 0
for entity in feed.entity:
    n += 1

    if entity.HasField('trip_update'):
        tid = entity.trip_update.trip.trip_id
        updates[tid]['trip_update'] = entity.trip_update
        updates[tid]['trip'] = entity.trip_update.trip
    
    if entity.HasField('vehicle'):
        tid = entity.vehicle.trip.trip_id
        updates[tid]['vehicle'] = entity.vehicle
    

print(n)
# Out:
# 51

# %%
for obj in dict(updates).values():
    print(obj)
    print('='*10)
# Out:
# {'trip': trip_id: "063650_L..N"
# start_date: "20250528"
# schedule_relationship: SCHEDULED
# route_id: "L"
# direction_id: 0
# , 'trip_update': trip {
#   trip_id: "063650_L..N"
#   start_date: "20250528"
#   schedule_relationship: SCHEDULED
#   route_id: "L"
#   direction_id: 0
# }
# stop_time_update {
#   stop_sequence: 20
#   arrival {
#     delay: 48
#     time: 1748444973
#     uncertainty: 0
#   }
#   departure {
#     delay: 48
#     time: 1748444988
#     uncertainty: 0
#   }
#   stop_id: "L05N"
#   schedule_relationship: SCHEDULED
# }
# stop_time_update {
#   stop_sequence: 21
#   arrival {
#     delay: 48
#     time: 1748445033
#     uncertainty: 0
#   }
#   departure {
#     delay: 48
#     time: 1748445048
#     uncertainty: 0
#   }
#   stop_id: "L03N"
#   schedule_relationship: SCHEDULED
# }
# stop_time_update {
#   stop_sequence: 22
#   arrival {
#     delay: 48
#     time: 1748445123
#     uncertainty: 0
#   }
#   departure {
#     delay: 48
#     time: 1748445138
#     uncertainty: 0
#   }
#   stop_id: "L02N"
#   schedule_relationship: SCHEDULED
# }
# stop_time_update {
#   stop_sequence: 23
#   arrival {
#     delay: 48
#     time: 1748445273
#     uncertainty: 0
#   }
#   stop_id: "L01N"
#   schedule_relationship: SCHEDULED
# }
# timestamp: 1748444962
# , 'vehicle': trip {
#   trip_id: "063650_L..N"
#   start_date: "20250528"
#   schedule_relationship: SCHEDULED
#   route_id: "L"
#   direction_id: 0
# }
# current_stop_sequence: 20
# current_status: IN_TRANSIT_TO
# timestamp: 1748444956
# congestion_level: UNKNOWN_CONGESTION_LEVEL
# stop_id: "L05N"
# }
# ==========
# {'trip': trip_id: "063850_L..S"
# start_date: "20250528"
# schedule_relationship: SCHEDULED
# route_id: "L"
# direction_id: 0
# , 'trip_update': trip {
#   trip_id: "063850_L..S"
#   start_date: "20250528"
#   schedule_relationship: SCHEDULED
#   route_id: "L"
#   direction_id: 0
# }
# stop_time_update {
#   stop_sequence: 19
#   arrival {
#     delay: -75
#     time: 1748444910
#     uncertainty: 0
#   }
#   departure {
#     delay: -75
#     time: 1748444925
#     uncertainty: 0
#   }
#   stop_id: "L25S"
#   schedule_relationship: SCHEDULED
# }
# stop_time_update {
#   stop_sequence: 20
#   arrival {
#     delay: -13
#     time: 1748445062
#     uncertainty: 0
#   }
#   departure {
#     delay: -13
#     time: 1748445077
#     uncertainty: 0
#   }
#   stop_id: "L26S"
#   schedule_relationship: SCHEDULED
# }
# stop_time_update {
#   stop_sequence: 21
#   arrival {
#     delay: -13
#     time: 1748445152
#     uncertainty: 0
#   }
#   departure {
#     delay: -13
#     time: 1748445167
#     uncertainty: 0
#   }
#   stop_id: "L27S"
#   schedule_relationship: SCHEDULED
# }
# stop_time_update {
#   stop_sequence: 22
#   arrival {
#     delay: -13
#     time: 1748445392
#     uncertainty: 0
#   }
#   departure {
#     delay: -13
#     time: 1748445407
#     uncertainty: 0
#   }
#   stop_id: "L28S"
#   schedule_relationship: SCHEDULED
# }
# stop_time_update {
#   stop_sequence: 23
#   arrival {
#     delay: -13
#     time: 1748445452
#     uncertainty: 0
#   }
#   stop_id: "L29S"
#   schedule_relationship: SCHEDULED
# }
# timestamp: 1748444962
# , 'vehicle': trip {
#   trip_id: "063850_L..S"
#   start_date: "20250528"
#   schedule_relationship: SCHEDULED
#   route_id: "L"
#   direction_id: 0
# }
# current_stop_sequence: 19
# current_status: STOPPED_AT
# timestamp: 1748444956
# congestion_level: UNKNOWN_CONGESTION_LEVEL
# stop_id: "L25S"
# }
# ==========
# {'trip': trip_id: "064050_L..N"
# start_date: "20250528"
# schedule_relationship: SCHEDULED
# route_id: "L"
# direction_id: 0
# , 'trip_update': trip {
#   trip_id: "064050_L..N"
#   start_date: "20250528"
#   schedule_relationship: SCHEDULED
#   route_id: "L"
#   direction_id: 0
# }
# stop_time_update {
#   stop_sequence: 19
#   arrival {
#     delay: -102
#     time: 1748445003
#     uncertainty: 0
#   }
#   departure {
#     delay: -102
#     time: 1748445018
#     uncertainty: 0
#   }
#   stop_id: "L06N"
#   schedule_relationship: SCHEDULED
# }
# stop_time_update {
#   stop_sequence: 20
#   arrival {
#     delay: -102
#     time: 1748445063
#     uncertainty: 0
#   }
#   departure {
#     delay: -102
#     time: 1748445078
#     uncertainty: 0
#   }
#   stop_id: "L05N"
#   schedule_relationship: SCHEDULED
# }
# stop_time_update {
#   stop_sequence: 21
#   arrival {
#     delay: -102
#     time: 1748445123
#     uncertainty: 0
#   }
#   departure {
#     delay: -102
#     time: 1748445138
#     uncertainty: 0
#   }
#   stop_id: "L03N"
#   schedule_relationship: SCHEDULED
# }
# stop_time_update {
#   stop_sequence: 22
#   arrival {
#     delay: -102
#     time: 1748445213
#     uncertainty: 0
#   }
#   departure {
#     delay: -102
#     time: 1748445228
#     uncertainty: 0
#   }
#   stop_id: "L02N"
#   schedule_relationship: SCHEDULED
# }
# stop_time_update {
#   stop_sequence: 23
#   arrival {
#     delay: -102
#     time: 1748445363
#     uncertainty: 0
#   }
#   stop_id: "L01N"
#   schedule_relationship: SCHEDULED
# }
# timestamp: 1748444962
# , 'vehicle': trip {
#   trip_id: "064050_L..N"
#   start_date: "20250528"
#   schedule_relationship: SCHEDULED
#   route_id: "L"
#   direction_id: 0
# }
# current_stop_sequence: 19
# current_status: IN_TRANSIT_TO
# timestamp: 1748444956
# congestion_level: UNKNOWN_CONGESTION_LEVEL
# stop_id: "L06N"
# }
# ==========
# {'trip': trip_id: "064250_L..S"
# start_date: "20250528"
# schedule_relationship: SCHEDULED
# route_id: "L"
# direction_id: 0
# , 'trip_update': trip {
#   trip_id: "064250_L..S"
#   start_date: "20250528"
#   schedule_relationship: SCHEDULED
#   route_id: "L"
#   direction_id: 0
# }
# stop_time_update {
#   stop_sequence: 18
#   arrival {
#     delay: -128
#     time: 1748445007
#     uncertainty: 0
#   }
#   departure {
#     delay: -128
#     time: 1748445022
#     uncertainty: 0
#   }
#   stop_id: "L24S"
#   schedule_relationship: SCHEDULED
# }
# stop_time_update {
#   stop_sequence: 19
#   arrival {
#     delay: -210
#     time: 1748445015
#     uncertainty: 0
#   }
#   departure {
#     delay: -210
#     time: 1748445030
#     uncertainty: 0
#   }
#   stop_id: "L25S"
#   schedule_relationship: SCHEDULED
# }
# stop_time_update {
#   stop_sequence: 20
#   arrival {
#     delay: -210
#     time: 1748445105
#     uncertainty: 0
#   }
#   departure {
#     delay: -210
#     time: 1748445120
#     uncertainty: 0
#   }
#   stop_id: "L26S"
#   schedule_relationship: SCHEDULED
# }
# stop_time_update {
#   stop_sequence: 21
#   arrival {
#     delay: -210
#     time: 1748445195
#     uncertainty: 0
#   }
#   departure {
#     delay: -210
#     time: 1748445210
#     uncertainty: 0
#   }
#   stop_id: "L27S"
#   schedule_relationship: SCHEDULED
# }
# stop_time_update {
#   stop_sequence: 22
#   arrival {
#     delay: -210
#     time: 1748445435
#     uncertainty: 0
#   }
#   departure {
#     delay: -210
#     time: 1748445450
#     uncertainty: 0
#   }
#   stop_id: "L28S"
#   schedule_relationship: SCHEDULED
# }
# stop_time_update {
#   stop_sequence: 23
#   arrival {
#     delay: -210
#     time: 1748445495
#     uncertainty: 0
#   }
#   stop_id: "L29S"
#   schedule_relationship: SCHEDULED
# }
# timestamp: 1748444962
# , 'vehicle': trip {
#   trip_id: "064250_L..S"
#   start_date: "20250528"
#   schedule_relationship: SCHEDULED
#   route_id: "L"
#   direction_id: 0
# }
# current_stop_sequence: 18
# current_status: STOPPED_AT
# timestamp: 1748444925
# congestion_level: UNKNOWN_CONGESTION_LEVEL
# stop_id: "L24S"
# }
# ==========
# {'trip': trip_id: "064450_L..N"
# start_date: "20250528"
# schedule_relationship: SCHEDULED
# route_id: "L"
# direction_id: 0
# , 'trip_update': trip {
#   trip_id: "064450_L..N"
#   start_date: "20250528"
#   schedule_relationship: SCHEDULED
#   route_id: "L"
#   direction_id: 0
# }
# stop_time_update {
#   stop_sequence: 17
#   arrival {
#     delay: -94
#     time: 1748444951
#     uncertainty: 0
#   }
#   departure {
#     delay: -94
#     time: 1748444966
#     uncertainty: 0
#   }
#   stop_id: "L10N"
#   schedule_relationship: SCHEDULED
# }
# stop_time_update {
#   stop_sequence: 18
#   arrival {
#     delay: -79
#     time: 1748445056
#     uncertainty: 0
#   }
#   departure {
#     delay: -79
#     time: 1748445071
#     uncertainty: 0
#   }
#   stop_id: "L08N"
#   schedule_relationship: SCHEDULED
# }
# stop_time_update {
#   stop_sequence: 19
#   arrival {
#     delay: -79
#     time: 1748445266
#     uncertainty: 0
#   }
#   departure {
#     delay: -79
#     time: 1748445281
#     uncertainty: 0
#   }
#   stop_id: "L06N"
#   schedule_relationship: SCHEDULED
# }
# stop_time_update {
#   stop_sequence: 20
#   arrival {
#     delay: -79
#     time: 1748445326
#     uncertainty: 0
#   }
#   departure {
#     delay: -79
#     time: 1748445341
#     uncertainty: 0
#   }
#   stop_id: "L05N"
#   schedule_relationship: SCHEDULED
# }
# stop_time_update {
#   stop_sequence: 21
#   arrival {
#     delay: -79
#     time: 1748445386
#     uncertainty: 0
#   }
#   departure {
#     delay: -79
#     time: 1748445401
#     uncertainty: 0
#   }
#   stop_id: "L03N"
#   schedule_relationship: SCHEDULED
# }
# stop_time_update {
#   stop_sequence: 22
#   arrival {
#     delay: -79
#     time: 1748445476
#     uncertainty: 0
#   }
#   departure {
#     delay: -79
#     time: 1748445491
#     uncertainty: 0
#   }
#   stop_id: "L02N"
#   schedule_relationship: SCHEDULED
# }
# stop_time_update {
#   stop_sequence: 23
#   arrival {
#     delay: -79
#     time: 1748445626
#     uncertainty: 0
#   }
#   stop_id: "L01N"
#   schedule_relationship: SCHEDULED
# }
# timestamp: 1748444962
# , 'vehicle': trip {
#   trip_id: "064450_L..N"
#   start_date: "20250528"
#   schedule_relationship: SCHEDULED
#   route_id: "L"
#   direction_id: 0
# }
# current_stop_sequence: 17
# current_status: STOPPED_AT
# timestamp: 1748444956
# congestion_level: UNKNOWN_CONGESTION_LEVEL
# stop_id: "L10N"
# }
# ==========
# {'trip': trip_id: "064650_L..S"
# start_date: "20250528"
# schedule_relationship: SCHEDULED
# route_id: "L"
# direction_id: 0
# , 'trip_update': trip {
#   trip_id: "064650_L..S"
#   start_date: "20250528"
#   schedule_relationship: SCHEDULED
#   route_id: "L"
#   direction_id: 0
# }
# stop_time_update {
#   stop_sequence: 15
#   arrival {
#     delay: 42
#     time: 1748445057
#     uncertainty: 0
#   }
#   departure {
#     delay: 42
#     time: 1748445072
#     uncertainty: 0
#   }
#   stop_id: "L20S"
#   schedule_relationship: SCHEDULED
# }
# stop_time_update {
#   stop_sequence: 16
#   arrival {
#     delay: 42
#     time: 1748445147
#     uncertainty: 0
#   }
#   departure {
#     delay: 42
#     time: 1748445162
#     uncertainty: 0
#   }
#   stop_id: "L21S"
#   schedule_relationship: SCHEDULED
# }
# stop_time_update {
#   stop_sequence: 17
#   arrival {
#     delay: 42
#     time: 1748445327
#     uncertainty: 0
#   }
#   departure {
#     delay: 42
#     time: 1748445342
#     uncertainty: 0
#   }
#   stop_id: "L22S"
#   schedule_relationship: SCHEDULED
# }
# stop_time_update {
#   stop_sequence: 18
#   arrival {
#     delay: 42
#     time: 1748445417
#     uncertainty: 0
#   }
#   departure {
#     delay: 42
#     time: 1748445432
#     uncertainty: 0
#   }
#   stop_id: "L24S"
#   schedule_relationship: SCHEDULED
# }
# stop_time_update {
#   stop_sequence: 19
#   arrival {
#     delay: 42
#     time: 1748445507
#     uncertainty: 0
#   }
#   departure {
#     delay: 42
#     time: 1748445522
#     uncertainty: 0
#   }
#   stop_id: "L25S"
#   schedule_relationship: SCHEDULED
# }
# stop_time_update {
#   stop_sequence: 20
#   arrival {
#     delay: 42
#     time: 1748445597
#     uncertainty: 0
#   }
#   departure {
#     delay: 42
#     time: 1748445612
#     uncertainty: 0
#   }
#   stop_id: "L26S"
#   schedule_relationship: SCHEDULED
# }
# stop_time_update {
#   stop_sequence: 21
#   arrival {
#     delay: 42
#     time: 1748445687
#     uncertainty: 0
#   }
#   departure {
#     delay: 42
#     time: 1748445702
#     uncertainty: 0
#   }
#   stop_id: "L27S"
#   schedule_relationship: SCHEDULED
# }
# stop_time_update {
#   stop_sequence: 22
#   arrival {
#     delay: 42
#     time: 1748445927
#     uncertainty: 0
#   }
#   departure {
#     delay: 42
#     time: 1748445942
#     uncertainty: 0
#   }
#   stop_id: "L28S"
#   schedule_relationship: SCHEDULED
# }
# stop_time_update {
#   stop_sequence: 23
#   arrival {
#     delay: 42
#     time: 1748445987
#     uncertainty: 0
#   }
#   stop_id: "L29S"
#   schedule_relationship: SCHEDULED
# }
# timestamp: 1748444962
# , 'vehicle': trip {
#   trip_id: "064650_L..S"
#   start_date: "20250528"
#   schedule_relationship: SCHEDULED
#   route_id: "L"
#   direction_id: 0
# }
# current_stop_sequence: 15
# current_status: IN_TRANSIT_TO
# timestamp: 1748444949
# congestion_level: UNKNOWN_CONGESTION_LEVEL
# stop_id: "L20S"
# }
# ==========
# {'trip': trip_id: "064850_L..N"
# start_date: "20250528"
# schedule_relationship: SCHEDULED
# route_id: "L"
# direction_id: 0
# , 'trip_update': trip {
#   trip_id: "064850_L..N"
#   start_date: "20250528"
#   schedule_relationship: SCHEDULED
#   route_id: "L"
#   direction_id: 0
# }
# stop_time_update {
#   stop_sequence: 14
#   arrival {
#     delay: -94
#     time: 1748444981
#     uncertainty: 0
#   }
#   departure {
#     delay: -94
#     time: 1748444996
#     uncertainty: 0
#   }
#   stop_id: "L13N"
#   schedule_relationship: SCHEDULED
# }
# stop_time_update {
#   stop_sequence: 15
#   arrival {
#     delay: -94
#     time: 1748445041
#     uncertainty: 0
#   }
#   departure {
#     delay: -94
#     time: 1748445056
#     uncertainty: 0
#   }
#   stop_id: "L12N"
#   schedule_relationship: SCHEDULED
# }
# stop_time_update {
#   stop_sequence: 16
#   arrival {
#     delay: -94
#     time: 1748445131
#     uncertainty: 0
#   }
#   departure {
#     delay: -94
#     time: 1748445146
#     uncertainty: 0
#   }
#   stop_id: "L11N"
#   schedule_relationship: SCHEDULED
# }
# stop_time_update {
#   stop_sequence: 17
#   arrival {
#     delay: -94
#     time: 1748445191
#     uncertainty: 0
#   }
#   departure {
#     delay: -94
#     time: 1748445206
#     uncertainty: 0
#   }
#   stop_id: "L10N"
#   schedule_relationship: SCHEDULED
# }
# stop_time_update {
#   stop_sequence: 18
#   arrival {
#     delay: -94
#     time: 1748445281
#     uncertainty: 0
#   }
#   departure {
#     delay: -94
#     time: 1748445296
#     uncertainty: 0
#   }
#   stop_id: "L08N"
#   schedule_relationship: SCHEDULED
# }
# stop_time_update {
#   stop_sequence: 19
#   arrival {
#     delay: -94
#     time: 1748445491
#     uncertainty: 0
#   }
#   departure {
#     delay: -94
#     time: 1748445506
#     uncertainty: 0
#   }
#   stop_id: "L06N"
#   schedule_relationship: SCHEDULED
# }
# stop_time_update {
#   stop_sequence: 20
#   arrival {
#     delay: -94
#     time: 1748445551
#     uncertainty: 0
#   }
#   departure {
#     delay: -94
#     time: 1748445566
#     uncertainty: 0
#   }
#   stop_id: "L05N"
#   schedule_relationship: SCHEDULED
# }
# stop_time_update {
#   stop_sequence: 21
#   arrival {
#     delay: -94
#     time: 1748445611
#     uncertainty: 0
#   }
#   departure {
#     delay: -94
#     time: 1748445626
#     uncertainty: 0
#   }
#   stop_id: "L03N"
#   schedule_relationship: SCHEDULED
# }
# stop_time_update {
#   stop_sequence: 22
#   arrival {
#     delay: -94
#     time: 1748445701
#     uncertainty: 0
#   }
#   departure {
#     delay: -94
#     time: 1748445716
#     uncertainty: 0
#   }
#   stop_id: "L02N"
#   schedule_relationship: SCHEDULED
# }
# stop_time_update {
#   stop_sequence: 23
#   arrival {
#     delay: -94
#     time: 1748445851
#     uncertainty: 0
#   }
#   stop_id: "L01N"
#   schedule_relationship: SCHEDULED
# }
# timestamp: 1748444962
# , 'vehicle': trip {
#   trip_id: "064850_L..N"
#   start_date: "20250528"
#   schedule_relationship: SCHEDULED
#   route_id: "L"
#   direction_id: 0
# }
# current_stop_sequence: 14
# current_status: IN_TRANSIT_TO
# timestamp: 1748444956
# congestion_level: UNKNOWN_CONGESTION_LEVEL
# stop_id: "L13N"
# }
# ==========
# {'trip': trip_id: "065050_L..S"
# start_date: "20250528"
# schedule_relationship: SCHEDULED
# route_id: "L"
# direction_id: 0
# , 'trip_update': trip {
#   trip_id: "065050_L..S"
#   start_date: "20250528"
#   schedule_relationship: SCHEDULED
#   route_id: "L"
#   direction_id: 0
# }
# stop_time_update {
#   stop_sequence: 11
#   arrival {
#     delay: 171
#     time: 1748445006
#     uncertainty: 0
#   }
#   departure {
#     delay: 171
#     time: 1748445021
#     uncertainty: 0
#   }
#   stop_id: "L15S"
#   schedule_relationship: SCHEDULED
# }
# stop_time_update {
#   stop_sequence: 12
#   arrival {
#     delay: 166
#     time: 1748445091
#     uncertainty: 0
#   }
#   departure {
#     delay: 166
#     time: 1748445106
#     uncertainty: 0
#   }
#   stop_id: "L16S"
#   schedule_relationship: SCHEDULED
# }
# stop_time_update {
#   stop_sequence: 13
#   arrival {
#     delay: 166
#     time: 1748445181
#     uncertainty: 0
#   }
#   departure {
#     delay: 166
#     time: 1748445196
#     uncertainty: 0
#   }
#   stop_id: "L17S"
#   schedule_relationship: SCHEDULED
# }
# stop_time_update {
#   stop_sequence: 14
#   arrival {
#     delay: 166
#     time: 1748445271
#     uncertainty: 0
#   }
#   departure {
#     delay: 166
#     time: 1748445286
#     uncertainty: 0
#   }
#   stop_id: "L19S"
#   schedule_relationship: SCHEDULED
# }
# stop_time_update {
#   stop_sequence: 15
#   arrival {
#     delay: 166
#     time: 1748445421
#     uncertainty: 0
#   }
#   departure {
#     delay: 166
#     time: 1748445436
#     uncertainty: 0
#   }
#   stop_id: "L20S"
#   schedule_relationship: SCHEDULED
# }
# stop_time_update {
#   stop_sequence: 16
#   arrival {
#     delay: 166
#     time: 1748445511
#     uncertainty: 0
#   }
#   departure {
#     delay: 166
#     time: 1748445526
#     uncertainty: 0
#   }
#   stop_id: "L21S"
#   schedule_relationship: SCHEDULED
# }
# stop_time_update {
#   stop_sequence: 17
#   arrival {
#     delay: 166
#     time: 1748445691
#     uncertainty: 0
#   }
#   departure {
#     delay: 166
#     time: 1748445706
#     uncertainty: 0
#   }
#   stop_id: "L22S"
#   schedule_relationship: SCHEDULED
# }
# stop_time_update {
#   stop_sequence: 18
#   arrival {
#     delay: 166
#     time: 1748445781
#     uncertainty: 0
#   }
#   departure {
#     delay: 166
#     time: 1748445796
#     uncertainty: 0
#   }
#   stop_id: "L24S"
#   schedule_relationship: SCHEDULED
# }
# stop_time_update {
#   stop_sequence: 19
#   arrival {
#     delay: 166
#     time: 1748445871
#     uncertainty: 0
#   }
#   departure {
#     delay: 166
#     time: 1748445886
#     uncertainty: 0
#   }
#   stop_id: "L25S"
#   schedule_relationship: SCHEDULED
# }
# stop_time_update {
#   stop_sequence: 20
#   arrival {
#     delay: 166
#     time: 1748445961
#     uncertainty: 0
#   }
#   departure {
#     delay: 166
#     time: 1748445976
#     uncertainty: 0
#   }
#   stop_id: "L26S"
#   schedule_relationship: SCHEDULED
# }
# stop_time_update {
#   stop_sequence: 21
#   arrival {
#     delay: 166
#     time: 1748446051
#     uncertainty: 0
#   }
#   departure {
#     delay: 166
#     time: 1748446066
#     uncertainty: 0
#   }
#   stop_id: "L27S"
#   schedule_relationship: SCHEDULED
# }
# stop_time_update {
#   stop_sequence: 22
#   arrival {
#     delay: 166
#     time: 1748446291
#     uncertainty: 0
#   }
#   departure {
#     delay: 166
#     time: 1748446306
#     uncertainty: 0
#   }
#   stop_id: "L28S"
#   schedule_relationship: SCHEDULED
# }
# stop_time_update {
#   stop_sequence: 23
#   arrival {
#     delay: 166
#     time: 1748446351
#     uncertainty: 0
#   }
#   stop_id: "L29S"
#   schedule_relationship: SCHEDULED
# }
# timestamp: 1748444962
# , 'vehicle': trip {
#   trip_id: "065050_L..S"
#   start_date: "20250528"
#   schedule_relationship: SCHEDULED
#   route_id: "L"
#   direction_id: 0
# }
# current_stop_sequence: 11
# current_status: STOPPED_AT
# timestamp: 1748444956
# congestion_level: UNKNOWN_CONGESTION_LEVEL
# stop_id: "L15S"
# }
# ==========
# {'trip': trip_id: "065250_L..N"
# start_date: "20250528"
# schedule_relationship: SCHEDULED
# route_id: "L"
# direction_id: 0
# , 'trip_update': trip {
#   trip_id: "065250_L..N"
#   start_date: "20250528"
#   schedule_relationship: SCHEDULED
#   route_id: "L"
#   direction_id: 0
# }
# stop_time_update {
#   stop_sequence: 12
#   arrival {
#     delay: -71
#     time: 1748445034
#     uncertainty: 0
#   }
#   departure {
#     delay: -71
#     time: 1748445049
#     uncertainty: 0
#   }
#   stop_id: "L15N"
#   schedule_relationship: SCHEDULED
# }
# stop_time_update {
#   stop_sequence: 13
#   arrival {
#     delay: -71
#     time: 1748445154
#     uncertainty: 0
#   }
#   departure {
#     delay: -71
#     time: 1748445169
#     uncertainty: 0
#   }
#   stop_id: "L14N"
#   schedule_relationship: SCHEDULED
# }
# stop_time_update {
#   stop_sequence: 14
#   arrival {
#     delay: -71
#     time: 1748445244
#     uncertainty: 0
#   }
#   departure {
#     delay: -71
#     time: 1748445259
#     uncertainty: 0
#   }
#   stop_id: "L13N"
#   schedule_relationship: SCHEDULED
# }
# stop_time_update {
#   stop_sequence: 15
#   arrival {
#     delay: -71
#     time: 1748445304
#     uncertainty: 0
#   }
#   departure {
#     delay: -71
#     time: 1748445319
#     uncertainty: 0
#   }
#   stop_id: "L12N"
#   schedule_relationship: SCHEDULED
# }
# stop_time_update {
#   stop_sequence: 16
#   arrival {
#     delay: -71
#     time: 1748445394
#     uncertainty: 0
#   }
#   departure {
#     delay: -71
#     time: 1748445409
#     uncertainty: 0
#   }
#   stop_id: "L11N"
#   schedule_relationship: SCHEDULED
# }
# stop_time_update {
#   stop_sequence: 17
#   arrival {
#     delay: -71
#     time: 1748445454
#     uncertainty: 0
#   }
#   departure {
#     delay: -71
#     time: 1748445469
#     uncertainty: 0
#   }
#   stop_id: "L10N"
#   schedule_relationship: SCHEDULED
# }
# stop_time_update {
#   stop_sequence: 18
#   arrival {
#     delay: -71
#     time: 1748445544
#     uncertainty: 0
#   }
#   departure {
#     delay: -71
#     time: 1748445559
#     uncertainty: 0
#   }
#   stop_id: "L08N"
#   schedule_relationship: SCHEDULED
# }
# stop_time_update {
#   stop_sequence: 19
#   arrival {
#     delay: -71
#     time: 1748445754
#     uncertainty: 0
#   }
#   departure {
#     delay: -71
#     time: 1748445769
#     uncertainty: 0
#   }
#   stop_id: "L06N"
#   schedule_relationship: SCHEDULED
# }
# stop_time_update {
#   stop_sequence: 20
#   arrival {
#     delay: -71
#     time: 1748445814
#     uncertainty: 0
#   }
#   departure {
#     delay: -71
#     time: 1748445829
#     uncertainty: 0
#   }
#   stop_id: "L05N"
#   schedule_relationship: SCHEDULED
# }
# stop_time_update {
#   stop_sequence: 21
#   arrival {
#     delay: -71
#     time: 1748445874
#     uncertainty: 0
#   }
#   departure {
#     delay: -71
#     time: 1748445889
#     uncertainty: 0
#   }
#   stop_id: "L03N"
#   schedule_relationship: SCHEDULED
# }
# stop_time_update {
#   stop_sequence: 22
#   arrival {
#     delay: -71
#     time: 1748445964
#     uncertainty: 0
#   }
#   departure {
#     delay: -71
#     time: 1748445979
#     uncertainty: 0
#   }
#   stop_id: "L02N"
#   schedule_relationship: SCHEDULED
# }
# stop_time_update {
#   stop_sequence: 23
#   arrival {
#     delay: -71
#     time: 1748446114
#     uncertainty: 0
#   }
#   stop_id: "L01N"
#   schedule_relationship: SCHEDULED
# }
# timestamp: 1748444962
# , 'vehicle': trip {
#   trip_id: "065250_L..N"
#   start_date: "20250528"
#   schedule_relationship: SCHEDULED
#   route_id: "L"
#   direction_id: 0
# }
# current_stop_sequence: 12
# current_status: IN_TRANSIT_TO
# timestamp: 1748444956
# congestion_level: UNKNOWN_CONGESTION_LEVEL
# stop_id: "L15N"
# }
# ==========
# {'trip': trip_id: "065450_L..S"
# start_date: "20250528"
# schedule_relationship: SCHEDULED
# route_id: "L"
# direction_id: 0
# , 'trip_update': trip {
#   trip_id: "065450_L..S"
#   start_date: "20250528"
#   schedule_relationship: SCHEDULED
#   route_id: "L"
#   direction_id: 0
# }
# stop_time_update {
#   stop_sequence: 10
#   arrival {
#     delay: 61
#     time: 1748445016
#     uncertainty: 0
#   }
#   departure {
#     delay: 61
#     time: 1748445031
#     uncertainty: 0
#   }
#   stop_id: "L14S"
#   schedule_relationship: SCHEDULED
# }
# stop_time_update {
#   stop_sequence: 11
#   arrival {
#     delay: 61
#     time: 1748445136
#     uncertainty: 0
#   }
#   departure {
#     delay: 61
#     time: 1748445151
#     uncertainty: 0
#   }
#   stop_id: "L15S"
#   schedule_relationship: SCHEDULED
# }
# stop_time_update {
#   stop_sequence: 12
#   arrival {
#     delay: 61
#     time: 1748445226
#     uncertainty: 0
#   }
#   departure {
#     delay: 61
#     time: 1748445241
#     uncertainty: 0
#   }
#   stop_id: "L16S"
#   schedule_relationship: SCHEDULED
# }
# stop_time_update {
#   stop_sequence: 13
#   arrival {
#     delay: 61
#     time: 1748445316
#     uncertainty: 0
#   }
#   departure {
#     delay: 61
#     time: 1748445331
#     uncertainty: 0
#   }
#   stop_id: "L17S"
#   schedule_relationship: SCHEDULED
# }
# stop_time_update {
#   stop_sequence: 14
#   arrival {
#     delay: 61
#     time: 1748445406
#     uncertainty: 0
#   }
#   departure {
#     delay: 61
#     time: 1748445421
#     uncertainty: 0
#   }
#   stop_id: "L19S"
#   schedule_relationship: SCHEDULED
# }
# stop_time_update {
#   stop_sequence: 15
#   arrival {
#     delay: 61
#     time: 1748445556
#     uncertainty: 0
#   }
#   departure {
#     delay: 61
#     time: 1748445571
#     uncertainty: 0
#   }
#   stop_id: "L20S"
#   schedule_relationship: SCHEDULED
# }
# stop_time_update {
#   stop_sequence: 16
#   arrival {
#     delay: 61
#     time: 1748445646
#     uncertainty: 0
#   }
#   departure {
#     delay: 61
#     time: 1748445661
#     uncertainty: 0
#   }
#   stop_id: "L21S"
#   schedule_relationship: SCHEDULED
# }
# stop_time_update {
#   stop_sequence: 17
#   arrival {
#     delay: 61
#     time: 1748445826
#     uncertainty: 0
#   }
#   departure {
#     delay: 61
#     time: 1748445841
#     uncertainty: 0
#   }
#   stop_id: "L22S"
#   schedule_relationship: SCHEDULED
# }
# stop_time_update {
#   stop_sequence: 18
#   arrival {
#     delay: 61
#     time: 1748445916
#     uncertainty: 0
#   }
#   departure {
#     delay: 61
#     time: 1748445931
#     uncertainty: 0
#   }
#   stop_id: "L24S"
#   schedule_relationship: SCHEDULED
# }
# stop_time_update {
#   stop_sequence: 19
#   arrival {
#     delay: 61
#     time: 1748446006
#     uncertainty: 0
#   }
#   departure {
#     delay: 61
#     time: 1748446021
#     uncertainty: 0
#   }
#   stop_id: "L25S"
#   schedule_relationship: SCHEDULED
# }
# stop_time_update {
#   stop_sequence: 20
#   arrival {
#     delay: 61
#     time: 1748446096
#     uncertainty: 0
#   }
#   departure {
#     delay: 61
#     time: 1748446111
#     uncertainty: 0
#   }
#   stop_id: "L26S"
#   schedule_relationship: SCHEDULED
# }
# stop_time_update {
#   stop_sequence: 21
#   arrival {
#     delay: 61
#     time: 1748446186
#     uncertainty: 0
#   }
#   departure {
#     delay: 61
#     time: 1748446201
#     uncertainty: 0
#   }
#   stop_id: "L27S"
#   schedule_relationship: SCHEDULED
# }
# stop_time_update {
#   stop_sequence: 22
#   arrival {
#     delay: 61
#     time: 1748446426
#     uncertainty: 0
#   }
#   departure {
#     delay: 61
#     time: 1748446441
#     uncertainty: 0
#   }
#   stop_id: "L28S"
#   schedule_relationship: SCHEDULED
# }
# stop_time_update {
#   stop_sequence: 23
#   arrival {
#     delay: 61
#     time: 1748446486
#     uncertainty: 0
#   }
#   stop_id: "L29S"
#   schedule_relationship: SCHEDULED
# }
# timestamp: 1748444962
# , 'vehicle': trip {
#   trip_id: "065450_L..S"
#   start_date: "20250528"
#   schedule_relationship: SCHEDULED
#   route_id: "L"
#   direction_id: 0
# }
# current_stop_sequence: 10
# current_status: IN_TRANSIT_TO
# timestamp: 1748444949
# congestion_level: UNKNOWN_CONGESTION_LEVEL
# stop_id: "L14S"
# }
# ==========
# {'trip': trip_id: "065650_L..N"
# start_date: "20250528"
# schedule_relationship: SCHEDULED
# route_id: "L"
# direction_id: 0
# , 'trip_update': trip {
#   trip_id: "065650_L..N"
#   start_date: "20250528"
#   schedule_relationship: SCHEDULED
#   route_id: "L"
#   direction_id: 0
# }
# stop_time_update {
#   stop_sequence: 9
#   arrival {
#     delay: -66
#     time: 1748445009
#     uncertainty: 0
#   }
#   departure {
#     delay: -66
#     time: 1748445024
#     uncertainty: 0
#   }
#   stop_id: "L19N"
#   schedule_relationship: SCHEDULED
# }
# stop_time_update {
#   stop_sequence: 10
#   arrival {
#     delay: -69
#     time: 1748445096
#     uncertainty: 0
#   }
#   departure {
#     delay: -69
#     time: 1748445111
#     uncertainty: 0
#   }
#   stop_id: "L17N"
#   schedule_relationship: SCHEDULED
# }
# stop_time_update {
#   stop_sequence: 11
#   arrival {
#     delay: -69
#     time: 1748445186
#     uncertainty: 0
#   }
#   departure {
#     delay: -69
#     time: 1748445201
#     uncertainty: 0
#   }
#   stop_id: "L16N"
#   schedule_relationship: SCHEDULED
# }
# stop_time_update {
#   stop_sequence: 12
#   arrival {
#     delay: -69
#     time: 1748445276
#     uncertainty: 0
#   }
#   departure {
#     delay: -69
#     time: 1748445291
#     uncertainty: 0
#   }
#   stop_id: "L15N"
#   schedule_relationship: SCHEDULED
# }
# stop_time_update {
#   stop_sequence: 13
#   arrival {
#     delay: -69
#     time: 1748445396
#     uncertainty: 0
#   }
#   departure {
#     delay: -69
#     time: 1748445411
#     uncertainty: 0
#   }
#   stop_id: "L14N"
#   schedule_relationship: SCHEDULED
# }
# stop_time_update {
#   stop_sequence: 14
#   arrival {
#     delay: -69
#     time: 1748445486
#     uncertainty: 0
#   }
#   departure {
#     delay: -69
#     time: 1748445501
#     uncertainty: 0
#   }
#   stop_id: "L13N"
#   schedule_relationship: SCHEDULED
# }
# stop_time_update {
#   stop_sequence: 15
#   arrival {
#     delay: -69
#     time: 1748445546
#     uncertainty: 0
#   }
#   departure {
#     delay: -69
#     time: 1748445561
#     uncertainty: 0
#   }
#   stop_id: "L12N"
#   schedule_relationship: SCHEDULED
# }
# stop_time_update {
#   stop_sequence: 16
#   arrival {
#     delay: -69
#     time: 1748445636
#     uncertainty: 0
#   }
#   departure {
#     delay: -69
#     time: 1748445651
#     uncertainty: 0
#   }
#   stop_id: "L11N"
#   schedule_relationship: SCHEDULED
# }
# stop_time_update {
#   stop_sequence: 17
#   arrival {
#     delay: -69
#     time: 1748445696
#     uncertainty: 0
#   }
#   departure {
#     delay: -69
#     time: 1748445711
#     uncertainty: 0
#   }
#   stop_id: "L10N"
#   schedule_relationship: SCHEDULED
# }
# stop_time_update {
#   stop_sequence: 18
#   arrival {
#     delay: -69
#     time: 1748445786
#     uncertainty: 0
#   }
#   departure {
#     delay: -69
#     time: 1748445801
#     uncertainty: 0
#   }
#   stop_id: "L08N"
#   schedule_relationship: SCHEDULED
# }
# stop_time_update {
#   stop_sequence: 19
#   arrival {
#     delay: -69
#     time: 1748445996
#     uncertainty: 0
#   }
#   departure {
#     delay: -69
#     time: 1748446011
#     uncertainty: 0
#   }
#   stop_id: "L06N"
#   schedule_relationship: SCHEDULED
# }
# stop_time_update {
#   stop_sequence: 20
#   arrival {
#     delay: -69
#     time: 1748446056
#     uncertainty: 0
#   }
#   departure {
#     delay: -69
#     time: 1748446071
#     uncertainty: 0
#   }
#   stop_id: "L05N"
#   schedule_relationship: SCHEDULED
# }
# stop_time_update {
#   stop_sequence: 21
#   arrival {
#     delay: -69
#     time: 1748446116
#     uncertainty: 0
#   }
#   departure {
#     delay: -69
#     time: 1748446131
#     uncertainty: 0
#   }
#   stop_id: "L03N"
#   schedule_relationship: SCHEDULED
# }
# stop_time_update {
#   stop_sequence: 22
#   arrival {
#     delay: -69
#     time: 1748446206
#     uncertainty: 0
#   }
#   departure {
#     delay: -69
#     time: 1748446221
#     uncertainty: 0
#   }
#   stop_id: "L02N"
#   schedule_relationship: SCHEDULED
# }
# stop_time_update {
#   stop_sequence: 23
#   arrival {
#     delay: -69
#     time: 1748446356
#     uncertainty: 0
#   }
#   stop_id: "L01N"
#   schedule_relationship: SCHEDULED
# }
# timestamp: 1748444962
# , 'vehicle': trip {
#   trip_id: "065650_L..N"
#   start_date: "20250528"
#   schedule_relationship: SCHEDULED
#   route_id: "L"
#   direction_id: 0
# }
# current_stop_sequence: 9
# current_status: STOPPED_AT
# timestamp: 1748444956
# congestion_level: UNKNOWN_CONGESTION_LEVEL
# stop_id: "L19N"
# }
# ==========
# {'trip': trip_id: "065850_L..S"
# start_date: "20250528"
# schedule_relationship: SCHEDULED
# route_id: "L"
# direction_id: 0
# , 'trip_update': trip {
#   trip_id: "065850_L..S"
#   start_date: "20250528"
#   schedule_relationship: SCHEDULED
#   route_id: "L"
#   direction_id: 0
# }
# stop_time_update {
#   stop_sequence: 7
#   arrival {
#     delay: 21
#     time: 1748444976
#     uncertainty: 0
#   }
#   departure {
#     delay: 21
#     time: 1748444991
#     uncertainty: 0
#   }
#   stop_id: "L11S"
#   schedule_relationship: SCHEDULED
# }
# stop_time_update {
#   stop_sequence: 8
#   arrival {
#     delay: 20
#     time: 1748445065
#     uncertainty: 0
#   }
#   departure {
#     delay: 20
#     time: 1748445080
#     uncertainty: 0
#   }
#   stop_id: "L12S"
#   schedule_relationship: SCHEDULED
# }
# stop_time_update {
#   stop_sequence: 9
#   arrival {
#     delay: 20
#     time: 1748445125
#     uncertainty: 0
#   }
#   departure {
#     delay: 20
#     time: 1748445140
#     uncertainty: 0
#   }
#   stop_id: "L13S"
#   schedule_relationship: SCHEDULED
# }
# stop_time_update {
#   stop_sequence: 10
#   arrival {
#     delay: 20
#     time: 1748445215
#     uncertainty: 0
#   }
#   departure {
#     delay: 20
#     time: 1748445230
#     uncertainty: 0
#   }
#   stop_id: "L14S"
#   schedule_relationship: SCHEDULED
# }
# stop_time_update {
#   stop_sequence: 11
#   arrival {
#     delay: 20
#     time: 1748445335
#     uncertainty: 0
#   }
#   departure {
#     delay: 20
#     time: 1748445350
#     uncertainty: 0
#   }
#   stop_id: "L15S"
#   schedule_relationship: SCHEDULED
# }
# stop_time_update {
#   stop_sequence: 12
#   arrival {
#     delay: 20
#     time: 1748445425
#     uncertainty: 0
#   }
#   departure {
#     delay: 20
#     time: 1748445440
#     uncertainty: 0
#   }
#   stop_id: "L16S"
#   schedule_relationship: SCHEDULED
# }
# stop_time_update {
#   stop_sequence: 13
#   arrival {
#     delay: 20
#     time: 1748445515
#     uncertainty: 0
#   }
#   departure {
#     delay: 20
#     time: 1748445530
#     uncertainty: 0
#   }
#   stop_id: "L17S"
#   schedule_relationship: SCHEDULED
# }
# stop_time_update {
#   stop_sequence: 14
#   arrival {
#     delay: 20
#     time: 1748445605
#     uncertainty: 0
#   }
#   departure {
#     delay: 20
#     time: 1748445620
#     uncertainty: 0
#   }
#   stop_id: "L19S"
#   schedule_relationship: SCHEDULED
# }
# stop_time_update {
#   stop_sequence: 15
#   arrival {
#     delay: 20
#     time: 1748445755
#     uncertainty: 0
#   }
#   departure {
#     delay: 20
#     time: 1748445770
#     uncertainty: 0
#   }
#   stop_id: "L20S"
#   schedule_relationship: SCHEDULED
# }
# stop_time_update {
#   stop_sequence: 16
#   arrival {
#     delay: 20
#     time: 1748445845
#     uncertainty: 0
#   }
#   departure {
#     delay: 20
#     time: 1748445860
#     uncertainty: 0
#   }
#   stop_id: "L21S"
#   schedule_relationship: SCHEDULED
# }
# stop_time_update {
#   stop_sequence: 17
#   arrival {
#     delay: 20
#     time: 1748446025
#     uncertainty: 0
#   }
#   departure {
#     delay: 20
#     time: 1748446040
#     uncertainty: 0
#   }
#   stop_id: "L22S"
#   schedule_relationship: SCHEDULED
# }
# stop_time_update {
#   stop_sequence: 18
#   arrival {
#     delay: 20
#     time: 1748446115
#     uncertainty: 0
#   }
#   departure {
#     delay: 20
#     time: 1748446130
#     uncertainty: 0
#   }
#   stop_id: "L24S"
#   schedule_relationship: SCHEDULED
# }
# stop_time_update {
#   stop_sequence: 19
#   arrival {
#     delay: 20
#     time: 1748446205
#     uncertainty: 0
#   }
#   departure {
#     delay: 20
#     time: 1748446220
#     uncertainty: 0
#   }
#   stop_id: "L25S"
#   schedule_relationship: SCHEDULED
# }
# stop_time_update {
#   stop_sequence: 20
#   arrival {
#     delay: 20
#     time: 1748446295
#     uncertainty: 0
#   }
#   departure {
#     delay: 20
#     time: 1748446310
#     uncertainty: 0
#   }
#   stop_id: "L26S"
#   schedule_relationship: SCHEDULED
# }
# stop_time_update {
#   stop_sequence: 21
#   arrival {
#     delay: 20
#     time: 1748446385
#     uncertainty: 0
#   }
#   departure {
#     delay: 20
#     time: 1748446400
#     uncertainty: 0
#   }
#   stop_id: "L27S"
#   schedule_relationship: SCHEDULED
# }
# stop_time_update {
#   stop_sequence: 22
#   arrival {
#     delay: 20
#     time: 1748446625
#     uncertainty: 0
#   }
#   departure {
#     delay: 20
#     time: 1748446640
#     uncertainty: 0
#   }
#   stop_id: "L28S"
#   schedule_relationship: SCHEDULED
# }
# stop_time_update {
#   stop_sequence: 23
#   arrival {
#     delay: 20
#     time: 1748446685
#     uncertainty: 0
#   }
#   stop_id: "L29S"
#   schedule_relationship: SCHEDULED
# }
# timestamp: 1748444962
# , 'vehicle': trip {
#   trip_id: "065850_L..S"
#   start_date: "20250528"
#   schedule_relationship: SCHEDULED
#   route_id: "L"
#   direction_id: 0
# }
# current_stop_sequence: 7
# current_status: IN_TRANSIT_TO
# timestamp: 1748444956
# congestion_level: UNKNOWN_CONGESTION_LEVEL
# stop_id: "L11S"
# }
# ==========
# {'trip': trip_id: "066050_L..N"
# start_date: "20250528"
# schedule_relationship: SCHEDULED
# route_id: "L"
# direction_id: 0
# , 'trip_update': trip {
#   trip_id: "066050_L..N"
#   start_date: "20250528"
#   schedule_relationship: SCHEDULED
#   route_id: "L"
#   direction_id: 0
# }
# stop_time_update {
#   stop_sequence: 6
#   arrival {
#     delay: -36
#     time: 1748444979
#     uncertainty: 0
#   }
#   departure {
#     delay: -36
#     time: 1748444994
#     uncertainty: 0
#   }
#   stop_id: "L22N"
#   schedule_relationship: SCHEDULED
# }
# stop_time_update {
#   stop_sequence: 7
#   arrival {
#     delay: -42
#     time: 1748445033
#     uncertainty: 0
#   }
#   departure {
#     delay: -42
#     time: 1748445048
#     uncertainty: 0
#   }
#   stop_id: "L21N"
#   schedule_relationship: SCHEDULED
# }
# stop_time_update {
#   stop_sequence: 8
#   arrival {
#     delay: -42
#     time: 1748445123
#     uncertainty: 0
#   }
#   departure {
#     delay: -42
#     time: 1748445138
#     uncertainty: 0
#   }
#   stop_id: "L20N"
#   schedule_relationship: SCHEDULED
# }
# stop_time_update {
#   stop_sequence: 9
#   arrival {
#     delay: -42
#     time: 1748445273
#     uncertainty: 0
#   }
#   departure {
#     delay: -42
#     time: 1748445288
#     uncertainty: 0
#   }
#   stop_id: "L19N"
#   schedule_relationship: SCHEDULED
# }
# stop_time_update {
#   stop_sequence: 10
#   arrival {
#     delay: -42
#     time: 1748445363
#     uncertainty: 0
#   }
#   departure {
#     delay: -42
#     time: 1748445378
#     uncertainty: 0
#   }
#   stop_id: "L17N"
#   schedule_relationship: SCHEDULED
# }
# stop_time_update {
#   stop_sequence: 11
#   arrival {
#     delay: -42
#     time: 1748445453
#     uncertainty: 0
#   }
#   departure {
#     delay: -42
#     time: 1748445468
#     uncertainty: 0
#   }
#   stop_id: "L16N"
#   schedule_relationship: SCHEDULED
# }
# stop_time_update {
#   stop_sequence: 12
#   arrival {
#     delay: -42
#     time: 1748445543
#     uncertainty: 0
#   }
#   departure {
#     delay: -42
#     time: 1748445558
#     uncertainty: 0
#   }
#   stop_id: "L15N"
#   schedule_relationship: SCHEDULED
# }
# stop_time_update {
#   stop_sequence: 13
#   arrival {
#     delay: -42
#     time: 1748445663
#     uncertainty: 0
#   }
#   departure {
#     delay: -42
#     time: 1748445678
#     uncertainty: 0
#   }
#   stop_id: "L14N"
#   schedule_relationship: SCHEDULED
# }
# stop_time_update {
#   stop_sequence: 14
#   arrival {
#     delay: -42
#     time: 1748445753
#     uncertainty: 0
#   }
#   departure {
#     delay: -42
#     time: 1748445768
#     uncertainty: 0
#   }
#   stop_id: "L13N"
#   schedule_relationship: SCHEDULED
# }
# stop_time_update {
#   stop_sequence: 15
#   arrival {
#     delay: -42
#     time: 1748445813
#     uncertainty: 0
#   }
#   departure {
#     delay: -42
#     time: 1748445828
#     uncertainty: 0
#   }
#   stop_id: "L12N"
#   schedule_relationship: SCHEDULED
# }
# stop_time_update {
#   stop_sequence: 16
#   arrival {
#     delay: -42
#     time: 1748445903
#     uncertainty: 0
#   }
#   departure {
#     delay: -42
#     time: 1748445918
#     uncertainty: 0
#   }
#   stop_id: "L11N"
#   schedule_relationship: SCHEDULED
# }
# stop_time_update {
#   stop_sequence: 17
#   arrival {
#     delay: -42
#     time: 1748445963
#     uncertainty: 0
#   }
#   departure {
#     delay: -42
#     time: 1748445978
#     uncertainty: 0
#   }
#   stop_id: "L10N"
#   schedule_relationship: SCHEDULED
# }
# stop_time_update {
#   stop_sequence: 18
#   arrival {
#     delay: -42
#     time: 1748446053
#     uncertainty: 0
#   }
#   departure {
#     delay: -42
#     time: 1748446068
#     uncertainty: 0
#   }
#   stop_id: "L08N"
#   schedule_relationship: SCHEDULED
# }
# stop_time_update {
#   stop_sequence: 19
#   arrival {
#     delay: -42
#     time: 1748446263
#     uncertainty: 0
#   }
#   departure {
#     delay: -42
#     time: 1748446278
#     uncertainty: 0
#   }
#   stop_id: "L06N"
#   schedule_relationship: SCHEDULED
# }
# stop_time_update {
#   stop_sequence: 20
#   arrival {
#     delay: -42
#     time: 1748446323
#     uncertainty: 0
#   }
#   departure {
#     delay: -42
#     time: 1748446338
#     uncertainty: 0
#   }
#   stop_id: "L05N"
#   schedule_relationship: SCHEDULED
# }
# stop_time_update {
#   stop_sequence: 21
#   arrival {
#     delay: -42
#     time: 1748446383
#     uncertainty: 0
#   }
#   departure {
#     delay: -42
#     time: 1748446398
#     uncertainty: 0
#   }
#   stop_id: "L03N"
#   schedule_relationship: SCHEDULED
# }
# stop_time_update {
#   stop_sequence: 22
#   arrival {
#     delay: -42
#     time: 1748446473
#     uncertainty: 0
#   }
#   departure {
#     delay: -42
#     time: 1748446488
#     uncertainty: 0
#   }
#   stop_id: "L02N"
#   schedule_relationship: SCHEDULED
# }
# stop_time_update {
#   stop_sequence: 23
#   arrival {
#     delay: -42
#     time: 1748446623
#     uncertainty: 0
#   }
#   stop_id: "L01N"
#   schedule_relationship: SCHEDULED
# }
# timestamp: 1748444962
# , 'vehicle': trip {
#   trip_id: "066050_L..N"
#   start_date: "20250528"
#   schedule_relationship: SCHEDULED
#   route_id: "L"
#   direction_id: 0
# }
# current_stop_sequence: 6
# current_status: STOPPED_AT
# timestamp: 1748444956
# congestion_level: UNKNOWN_CONGESTION_LEVEL
# stop_id: "L22N"
# }
# ==========
# {'trip': trip_id: "066250_L..S"
# start_date: "20250528"
# schedule_relationship: SCHEDULED
# route_id: "L"
# direction_id: 0
# , 'trip_update': trip {
#   trip_id: "066250_L..S"
#   start_date: "20250528"
#   schedule_relationship: SCHEDULED
#   route_id: "L"
#   direction_id: 0
# }
# stop_time_update {
#   stop_sequence: 5
#   arrival {
#     delay: -11
#     time: 1748445034
#     uncertainty: 0
#   }
#   departure {
#     delay: -11
#     time: 1748445049
#     uncertainty: 0
#   }
#   stop_id: "L08S"
#   schedule_relationship: SCHEDULED
# }
# stop_time_update {
#   stop_sequence: 6
#   arrival {
#     delay: -11
#     time: 1748445124
#     uncertainty: 0
#   }
#   departure {
#     delay: -11
#     time: 1748445139
#     uncertainty: 0
#   }
#   stop_id: "L10S"
#   schedule_relationship: SCHEDULED
# }
# stop_time_update {
#   stop_sequence: 7
#   arrival {
#     delay: -11
#     time: 1748445184
#     uncertainty: 0
#   }
#   departure {
#     delay: -11
#     time: 1748445199
#     uncertainty: 0
#   }
#   stop_id: "L11S"
#   schedule_relationship: SCHEDULED
# }
# stop_time_update {
#   stop_sequence: 8
#   arrival {
#     delay: -11
#     time: 1748445274
#     uncertainty: 0
#   }
#   departure {
#     delay: -11
#     time: 1748445289
#     uncertainty: 0
#   }
#   stop_id: "L12S"
#   schedule_relationship: SCHEDULED
# }
# stop_time_update {
#   stop_sequence: 9
#   arrival {
#     delay: -11
#     time: 1748445334
#     uncertainty: 0
#   }
#   departure {
#     delay: -11
#     time: 1748445349
#     uncertainty: 0
#   }
#   stop_id: "L13S"
#   schedule_relationship: SCHEDULED
# }
# stop_time_update {
#   stop_sequence: 10
#   arrival {
#     delay: -11
#     time: 1748445424
#     uncertainty: 0
#   }
#   departure {
#     delay: -11
#     time: 1748445439
#     uncertainty: 0
#   }
#   stop_id: "L14S"
#   schedule_relationship: SCHEDULED
# }
# stop_time_update {
#   stop_sequence: 11
#   arrival {
#     delay: -11
#     time: 1748445544
#     uncertainty: 0
#   }
#   departure {
#     delay: -11
#     time: 1748445559
#     uncertainty: 0
#   }
#   stop_id: "L15S"
#   schedule_relationship: SCHEDULED
# }
# stop_time_update {
#   stop_sequence: 12
#   arrival {
#     delay: -11
#     time: 1748445634
#     uncertainty: 0
#   }
#   departure {
#     delay: -11
#     time: 1748445649
#     uncertainty: 0
#   }
#   stop_id: "L16S"
#   schedule_relationship: SCHEDULED
# }
# stop_time_update {
#   stop_sequence: 13
#   arrival {
#     delay: -11
#     time: 1748445724
#     uncertainty: 0
#   }
#   departure {
#     delay: -11
#     time: 1748445739
#     uncertainty: 0
#   }
#   stop_id: "L17S"
#   schedule_relationship: SCHEDULED
# }
# stop_time_update {
#   stop_sequence: 14
#   arrival {
#     delay: -11
#     time: 1748445814
#     uncertainty: 0
#   }
#   departure {
#     delay: -11
#     time: 1748445829
#     uncertainty: 0
#   }
#   stop_id: "L19S"
#   schedule_relationship: SCHEDULED
# }
# stop_time_update {
#   stop_sequence: 15
#   arrival {
#     delay: -11
#     time: 1748445964
#     uncertainty: 0
#   }
#   departure {
#     delay: -11
#     time: 1748445979
#     uncertainty: 0
#   }
#   stop_id: "L20S"
#   schedule_relationship: SCHEDULED
# }
# stop_time_update {
#   stop_sequence: 16
#   arrival {
#     delay: -11
#     time: 1748446054
#     uncertainty: 0
#   }
#   departure {
#     delay: -11
#     time: 1748446069
#     uncertainty: 0
#   }
#   stop_id: "L21S"
#   schedule_relationship: SCHEDULED
# }
# stop_time_update {
#   stop_sequence: 17
#   arrival {
#     delay: -11
#     time: 1748446234
#     uncertainty: 0
#   }
#   departure {
#     delay: -11
#     time: 1748446249
#     uncertainty: 0
#   }
#   stop_id: "L22S"
#   schedule_relationship: SCHEDULED
# }
# stop_time_update {
#   stop_sequence: 18
#   arrival {
#     delay: -11
#     time: 1748446324
#     uncertainty: 0
#   }
#   departure {
#     delay: -11
#     time: 1748446339
#     uncertainty: 0
#   }
#   stop_id: "L24S"
#   schedule_relationship: SCHEDULED
# }
# stop_time_update {
#   stop_sequence: 19
#   arrival {
#     delay: -11
#     time: 1748446414
#     uncertainty: 0
#   }
#   departure {
#     delay: -11
#     time: 1748446429
#     uncertainty: 0
#   }
#   stop_id: "L25S"
#   schedule_relationship: SCHEDULED
# }
# stop_time_update {
#   stop_sequence: 20
#   arrival {
#     delay: -11
#     time: 1748446504
#     uncertainty: 0
#   }
#   departure {
#     delay: -11
#     time: 1748446519
#     uncertainty: 0
#   }
#   stop_id: "L26S"
#   schedule_relationship: SCHEDULED
# }
# stop_time_update {
#   stop_sequence: 21
#   arrival {
#     delay: -11
#     time: 1748446594
#     uncertainty: 0
#   }
#   departure {
#     delay: -11
#     time: 1748446609
#     uncertainty: 0
#   }
#   stop_id: "L27S"
#   schedule_relationship: SCHEDULED
# }
# stop_time_update {
#   stop_sequence: 22
#   arrival {
#     delay: -11
#     time: 1748446714
#     uncertainty: 0
#   }
#   departure {
#     delay: -11
#     time: 1748446729
#     uncertainty: 0
#   }
#   stop_id: "L28S"
#   schedule_relationship: SCHEDULED
# }
# stop_time_update {
#   stop_sequence: 23
#   arrival {
#     delay: -11
#     time: 1748446774
#     uncertainty: 0
#   }
#   stop_id: "L29S"
#   schedule_relationship: SCHEDULED
# }
# timestamp: 1748444962
# , 'vehicle': trip {
#   trip_id: "066250_L..S"
#   start_date: "20250528"
#   schedule_relationship: SCHEDULED
#   route_id: "L"
#   direction_id: 0
# }
# current_stop_sequence: 5
# current_status: IN_TRANSIT_TO
# timestamp: 1748444949
# congestion_level: UNKNOWN_CONGESTION_LEVEL
# stop_id: "L08S"
# }
# ==========
# {'trip': trip_id: "066450_L..N"
# start_date: "20250528"
# schedule_relationship: SCHEDULED
# route_id: "L"
# direction_id: 0
# , 'trip_update': trip {
#   trip_id: "066450_L..N"
#   start_date: "20250528"
#   schedule_relationship: SCHEDULED
#   route_id: "L"
#   direction_id: 0
# }
# stop_time_update {
#   stop_sequence: 4
#   arrival {
#     delay: -37
#     time: 1748445038
#     uncertainty: 0
#   }
#   departure {
#     delay: -37
#     time: 1748445053
#     uncertainty: 0
#   }
#   stop_id: "L25N"
#   schedule_relationship: SCHEDULED
# }
# stop_time_update {
#   stop_sequence: 5
#   arrival {
#     delay: -37
#     time: 1748445128
#     uncertainty: 0
#   }
#   departure {
#     delay: -37
#     time: 1748445143
#     uncertainty: 0
#   }
#   stop_id: "L24N"
#   schedule_relationship: SCHEDULED
# }
# stop_time_update {
#   stop_sequence: 6
#   arrival {
#     delay: -37
#     time: 1748445218
#     uncertainty: 0
#   }
#   departure {
#     delay: -37
#     time: 1748445233
#     uncertainty: 0
#   }
#   stop_id: "L22N"
#   schedule_relationship: SCHEDULED
# }
# stop_time_update {
#   stop_sequence: 7
#   arrival {
#     delay: -37
#     time: 1748445278
#     uncertainty: 0
#   }
#   departure {
#     delay: -37
#     time: 1748445293
#     uncertainty: 0
#   }
#   stop_id: "L21N"
#   schedule_relationship: SCHEDULED
# }
# stop_time_update {
#   stop_sequence: 8
#   arrival {
#     delay: -37
#     time: 1748445368
#     uncertainty: 0
#   }
#   departure {
#     delay: -37
#     time: 1748445383
#     uncertainty: 0
#   }
#   stop_id: "L20N"
#   schedule_relationship: SCHEDULED
# }
# stop_time_update {
#   stop_sequence: 9
#   arrival {
#     delay: -37
#     time: 1748445518
#     uncertainty: 0
#   }
#   departure {
#     delay: -37
#     time: 1748445533
#     uncertainty: 0
#   }
#   stop_id: "L19N"
#   schedule_relationship: SCHEDULED
# }
# stop_time_update {
#   stop_sequence: 10
#   arrival {
#     delay: -37
#     time: 1748445608
#     uncertainty: 0
#   }
#   departure {
#     delay: -37
#     time: 1748445623
#     uncertainty: 0
#   }
#   stop_id: "L17N"
#   schedule_relationship: SCHEDULED
# }
# stop_time_update {
#   stop_sequence: 11
#   arrival {
#     delay: -37
#     time: 1748445698
#     uncertainty: 0
#   }
#   departure {
#     delay: -37
#     time: 1748445713
#     uncertainty: 0
#   }
#   stop_id: "L16N"
#   schedule_relationship: SCHEDULED
# }
# stop_time_update {
#   stop_sequence: 12
#   arrival {
#     delay: -37
#     time: 1748445788
#     uncertainty: 0
#   }
#   departure {
#     delay: -37
#     time: 1748445803
#     uncertainty: 0
#   }
#   stop_id: "L15N"
#   schedule_relationship: SCHEDULED
# }
# stop_time_update {
#   stop_sequence: 13
#   arrival {
#     delay: -37
#     time: 1748445908
#     uncertainty: 0
#   }
#   departure {
#     delay: -37
#     time: 1748445923
#     uncertainty: 0
#   }
#   stop_id: "L14N"
#   schedule_relationship: SCHEDULED
# }
# stop_time_update {
#   stop_sequence: 14
#   arrival {
#     delay: -37
#     time: 1748445998
#     uncertainty: 0
#   }
#   departure {
#     delay: -37
#     time: 1748446013
#     uncertainty: 0
#   }
#   stop_id: "L13N"
#   schedule_relationship: SCHEDULED
# }
# stop_time_update {
#   stop_sequence: 15
#   arrival {
#     delay: -37
#     time: 1748446058
#     uncertainty: 0
#   }
#   departure {
#     delay: -37
#     time: 1748446073
#     uncertainty: 0
#   }
#   stop_id: "L12N"
#   schedule_relationship: SCHEDULED
# }
# stop_time_update {
#   stop_sequence: 16
#   arrival {
#     delay: -37
#     time: 1748446148
#     uncertainty: 0
#   }
#   departure {
#     delay: -37
#     time: 1748446163
#     uncertainty: 0
#   }
#   stop_id: "L11N"
#   schedule_relationship: SCHEDULED
# }
# stop_time_update {
#   stop_sequence: 17
#   arrival {
#     delay: -37
#     time: 1748446208
#     uncertainty: 0
#   }
#   departure {
#     delay: -37
#     time: 1748446223
#     uncertainty: 0
#   }
#   stop_id: "L10N"
#   schedule_relationship: SCHEDULED
# }
# stop_time_update {
#   stop_sequence: 18
#   arrival {
#     delay: -37
#     time: 1748446298
#     uncertainty: 0
#   }
#   departure {
#     delay: -37
#     time: 1748446313
#     uncertainty: 0
#   }
#   stop_id: "L08N"
#   schedule_relationship: SCHEDULED
# }
# stop_time_update {
#   stop_sequence: 19
#   arrival {
#     delay: -37
#     time: 1748446508
#     uncertainty: 0
#   }
#   departure {
#     delay: -37
#     time: 1748446523
#     uncertainty: 0
#   }
#   stop_id: "L06N"
#   schedule_relationship: SCHEDULED
# }
# stop_time_update {
#   stop_sequence: 20
#   arrival {
#     delay: -37
#     time: 1748446568
#     uncertainty: 0
#   }
#   departure {
#     delay: -37
#     time: 1748446583
#     uncertainty: 0
#   }
#   stop_id: "L05N"
#   schedule_relationship: SCHEDULED
# }
# stop_time_update {
#   stop_sequence: 21
#   arrival {
#     delay: -37
#     time: 1748446628
# ...
# }
# stop_time_update {
#   stop_sequence: 5
#   arrival {
#     delay: 0
#     time: 1748446965
#     uncertainty: 0
#   }
#   departure {
#     delay: 0
#     time: 1748446980
#     uncertainty: 0
#   }
#   stop_id: "L08S"
#   schedule_relationship: SCHEDULED
# }
# stop_time_update {
#   stop_sequence: 6
#   arrival {
#     delay: 0
#     time: 1748447055
#     uncertainty: 0
#   }
#   departure {
#     delay: 0
#     time: 1748447070
#     uncertainty: 0
#   }
#   stop_id: "L10S"
#   schedule_relationship: SCHEDULED
# }
# stop_time_update {
#   stop_sequence: 7
#   arrival {
#     delay: 0
#     time: 1748447115
#     uncertainty: 0
#   }
#   departure {
#     delay: 0
#     time: 1748447130
#     uncertainty: 0
#   }
#   stop_id: "L11S"
#   schedule_relationship: SCHEDULED
# }
# stop_time_update {
#   stop_sequence: 8
#   arrival {
#     delay: 0
#     time: 1748447205
#     uncertainty: 0
#   }
#   departure {
#     delay: 0
#     time: 1748447220
#     uncertainty: 0
#   }
#   stop_id: "L12S"
#   schedule_relationship: SCHEDULED
# }
# stop_time_update {
#   stop_sequence: 9
#   arrival {
#     delay: 0
#     time: 1748447265
#     uncertainty: 0
#   }
#   departure {
#     delay: 0
#     time: 1748447280
#     uncertainty: 0
#   }
#   stop_id: "L13S"
#   schedule_relationship: SCHEDULED
# }
# stop_time_update {
#   stop_sequence: 10
#   arrival {
#     delay: 0
#     time: 1748447355
#     uncertainty: 0
#   }
#   departure {
#     delay: 0
#     time: 1748447370
#     uncertainty: 0
#   }
#   stop_id: "L14S"
#   schedule_relationship: SCHEDULED
# }
# stop_time_update {
#   stop_sequence: 11
#   arrival {
#     delay: 0
#     time: 1748447475
#     uncertainty: 0
#   }
#   departure {
#     delay: 0
#     time: 1748447490
#     uncertainty: 0
#   }
#   stop_id: "L15S"
#   schedule_relationship: SCHEDULED
# }
# stop_time_update {
#   stop_sequence: 12
#   arrival {
#     delay: 0
#     time: 1748447565
#     uncertainty: 0
#   }
#   departure {
#     delay: 0
#     time: 1748447580
#     uncertainty: 0
#   }
#   stop_id: "L16S"
#   schedule_relationship: SCHEDULED
# }
# stop_time_update {
#   stop_sequence: 13
#   arrival {
#     delay: 0
#     time: 1748447655
#     uncertainty: 0
#   }
#   departure {
#     delay: 0
#     time: 1748447670
#     uncertainty: 0
#   }
#   stop_id: "L17S"
#   schedule_relationship: SCHEDULED
# }
# stop_time_update {
#   stop_sequence: 14
#   arrival {
#     delay: 0
#     time: 1748447745
#     uncertainty: 0
#   }
#   departure {
#     delay: 0
#     time: 1748447760
#     uncertainty: 0
#   }
#   stop_id: "L19S"
#   schedule_relationship: SCHEDULED
# }
# stop_time_update {
#   stop_sequence: 15
#   arrival {
#     delay: 0
#     time: 1748447895
#     uncertainty: 0
#   }
#   departure {
#     delay: 0
#     time: 1748447910
#     uncertainty: 0
#   }
#   stop_id: "L20S"
#   schedule_relationship: SCHEDULED
# }
# stop_time_update {
#   stop_sequence: 16
#   arrival {
#     delay: 0
#     time: 1748447985
#     uncertainty: 0
#   }
#   departure {
#     delay: 0
#     time: 1748448000
#     uncertainty: 0
#   }
#   stop_id: "L21S"
#   schedule_relationship: SCHEDULED
# }
# stop_time_update {
#   stop_sequence: 17
#   arrival {
#     delay: 0
#     time: 1748448045
#     uncertainty: 0
#   }
#   departure {
#     delay: 0
#     time: 1748448060
#     uncertainty: 0
#   }
#   stop_id: "L22S"
#   schedule_relationship: SCHEDULED
# }
# stop_time_update {
#   stop_sequence: 18
#   arrival {
#     delay: 0
#     time: 1748448135
#     uncertainty: 0
#   }
#   departure {
#     delay: 0
#     time: 1748448150
#     uncertainty: 0
#   }
#   stop_id: "L24S"
#   schedule_relationship: SCHEDULED
# }
# stop_time_update {
#   stop_sequence: 19
#   arrival {
#     delay: 0
#     time: 1748448225
#     uncertainty: 0
#   }
#   departure {
#     delay: 0
#     time: 1748448240
#     uncertainty: 0
#   }
#   stop_id: "L25S"
#   schedule_relationship: SCHEDULED
# }
# stop_time_update {
#   stop_sequence: 20
#   arrival {
#     delay: 0
#     time: 1748448315
#     uncertainty: 0
#   }
#   departure {
#     delay: 0
#     time: 1748448330
#     uncertainty: 0
#   }
#   stop_id: "L26S"
#   schedule_relationship: SCHEDULED
# }
# stop_time_update {
#   stop_sequence: 21
#   arrival {
#     delay: 0
#     time: 1748448405
#     uncertainty: 0
#   }
#   departure {
#     delay: 0
#     time: 1748448420
#     uncertainty: 0
#   }
#   stop_id: "L27S"
#   schedule_relationship: SCHEDULED
# }
# stop_time_update {
#   stop_sequence: 22
#   arrival {
#     delay: 0
#     time: 1748448525
#     uncertainty: 0
#   }
#   departure {
#     delay: 0
#     time: 1748448540
#     uncertainty: 0
#   }
#   stop_id: "L28S"
#   schedule_relationship: SCHEDULED
# }
# stop_time_update {
#   stop_sequence: 23
#   arrival {
#     delay: 0
#     time: 1748448585
#     uncertainty: 0
#   }
#   stop_id: "L29S"
#   schedule_relationship: SCHEDULED
# }
# timestamp: 1748444962
# , 'vehicle': {}}
# ==========
# {'trip': trip_id: "069850_L..S"
# start_date: "20250528"
# schedule_relationship: SCHEDULED
# route_id: "L"
# direction_id: 0
# , 'trip_update': trip {
#   trip_id: "069850_L..S"
#   start_date: "20250528"
#   schedule_relationship: SCHEDULED
#   route_id: "L"
#   direction_id: 0
# }
# stop_time_update {
#   stop_sequence: 0
#   departure {
#     delay: 0
#     time: 1748446710
#     uncertainty: 0
#   }
#   stop_id: "L01S"
#   schedule_relationship: SCHEDULED
# }
# stop_time_update {
#   stop_sequence: 1
#   arrival {
#     delay: 0
#     time: 1748446785
#     uncertainty: 0
#   }
#   departure {
#     delay: 0
#     time: 1748446800
#     uncertainty: 0
#   }
#   stop_id: "L02S"
#   schedule_relationship: SCHEDULED
# }
# stop_time_update {
#   stop_sequence: 2
#   arrival {
#     delay: 0
#     time: 1748446875
#     uncertainty: 0
#   }
#   departure {
#     delay: 0
#     time: 1748446890
#     uncertainty: 0
#   }
#   stop_id: "L03S"
#   schedule_relationship: SCHEDULED
# }
# stop_time_update {
#   stop_sequence: 3
#   arrival {
#     delay: 0
#     time: 1748446935
#     uncertainty: 0
#   }
#   departure {
#     delay: 0
#     time: 1748446950
#     uncertainty: 0
#   }
#   stop_id: "L05S"
#   schedule_relationship: SCHEDULED
# }
# stop_time_update {
#   stop_sequence: 4
#   arrival {
#     delay: 0
#     time: 1748446995
#     uncertainty: 0
#   }
#   departure {
#     delay: 0
#     time: 1748447010
#     uncertainty: 0
#   }
#   stop_id: "L06S"
#   schedule_relationship: SCHEDULED
# }
# stop_time_update {
#   stop_sequence: 5
#   arrival {
#     delay: 0
#     time: 1748447205
#     uncertainty: 0
#   }
#   departure {
#     delay: 0
#     time: 1748447220
#     uncertainty: 0
#   }
#   stop_id: "L08S"
#   schedule_relationship: SCHEDULED
# }
# stop_time_update {
#   stop_sequence: 6
#   arrival {
#     delay: 0
#     time: 1748447295
#     uncertainty: 0
#   }
#   departure {
#     delay: 0
#     time: 1748447310
#     uncertainty: 0
#   }
#   stop_id: "L10S"
#   schedule_relationship: SCHEDULED
# }
# stop_time_update {
#   stop_sequence: 7
#   arrival {
#     delay: 0
#     time: 1748447355
#     uncertainty: 0
#   }
#   departure {
#     delay: 0
#     time: 1748447370
#     uncertainty: 0
#   }
#   stop_id: "L11S"
#   schedule_relationship: SCHEDULED
# }
# stop_time_update {
#   stop_sequence: 8
#   arrival {
#     delay: 0
#     time: 1748447445
#     uncertainty: 0
#   }
#   departure {
#     delay: 0
#     time: 1748447460
#     uncertainty: 0
#   }
#   stop_id: "L12S"
#   schedule_relationship: SCHEDULED
# }
# stop_time_update {
#   stop_sequence: 9
#   arrival {
#     delay: 0
#     time: 1748447505
#     uncertainty: 0
#   }
#   departure {
#     delay: 0
#     time: 1748447520
#     uncertainty: 0
#   }
#   stop_id: "L13S"
#   schedule_relationship: SCHEDULED
# }
# stop_time_update {
#   stop_sequence: 10
#   arrival {
#     delay: 0
#     time: 1748447595
#     uncertainty: 0
#   }
#   departure {
#     delay: 0
#     time: 1748447610
#     uncertainty: 0
#   }
#   stop_id: "L14S"
#   schedule_relationship: SCHEDULED
# }
# stop_time_update {
#   stop_sequence: 11
#   arrival {
#     delay: 0
#     time: 1748447715
#     uncertainty: 0
#   }
#   departure {
#     delay: 0
#     time: 1748447730
#     uncertainty: 0
#   }
#   stop_id: "L15S"
#   schedule_relationship: SCHEDULED
# }
# stop_time_update {
#   stop_sequence: 12
#   arrival {
#     delay: 0
#     time: 1748447805
#     uncertainty: 0
#   }
#   departure {
#     delay: 0
#     time: 1748447820
#     uncertainty: 0
#   }
#   stop_id: "L16S"
#   schedule_relationship: SCHEDULED
# }
# stop_time_update {
#   stop_sequence: 13
#   arrival {
#     delay: 0
#     time: 1748447895
#     uncertainty: 0
#   }
#   departure {
#     delay: 0
#     time: 1748447910
#     uncertainty: 0
#   }
#   stop_id: "L17S"
#   schedule_relationship: SCHEDULED
# }
# stop_time_update {
#   stop_sequence: 14
#   arrival {
#     delay: 0
#     time: 1748447985
#     uncertainty: 0
#   }
#   departure {
#     delay: 0
#     time: 1748448000
#     uncertainty: 0
#   }
#   stop_id: "L19S"
#   schedule_relationship: SCHEDULED
# }
# stop_time_update {
#   stop_sequence: 15
#   arrival {
#     delay: 0
#     time: 1748448135
#     uncertainty: 0
#   }
#   departure {
#     delay: 0
#     time: 1748448150
#     uncertainty: 0
#   }
#   stop_id: "L20S"
#   schedule_relationship: SCHEDULED
# }
# stop_time_update {
#   stop_sequence: 16
#   arrival {
#     delay: 0
#     time: 1748448225
#     uncertainty: 0
#   }
#   departure {
#     delay: 0
#     time: 1748448240
#     uncertainty: 0
#   }
#   stop_id: "L21S"
#   schedule_relationship: SCHEDULED
# }
# stop_time_update {
#   stop_sequence: 17
#   arrival {
#     delay: 0
#     time: 1748448285
#     uncertainty: 0
#   }
#   departure {
#     delay: 0
#     time: 1748448300
#     uncertainty: 0
#   }
#   stop_id: "L22S"
#   schedule_relationship: SCHEDULED
# }
# stop_time_update {
#   stop_sequence: 18
#   arrival {
#     delay: 0
#     time: 1748448375
#     uncertainty: 0
#   }
#   departure {
#     delay: 0
#     time: 1748448390
#     uncertainty: 0
#   }
#   stop_id: "L24S"
#   schedule_relationship: SCHEDULED
# }
# stop_time_update {
#   stop_sequence: 19
#   arrival {
#     delay: 0
#     time: 1748448465
#     uncertainty: 0
#   }
#   departure {
#     delay: 0
#     time: 1748448480
#     uncertainty: 0
#   }
#   stop_id: "L25S"
#   schedule_relationship: SCHEDULED
# }
# stop_time_update {
#   stop_sequence: 20
#   arrival {
#     delay: 0
#     time: 1748448555
#     uncertainty: 0
#   }
#   departure {
#     delay: 0
#     time: 1748448570
#     uncertainty: 0
#   }
#   stop_id: "L26S"
#   schedule_relationship: SCHEDULED
# }
# stop_time_update {
#   stop_sequence: 21
#   arrival {
#     delay: 0
#     time: 1748448645
#     uncertainty: 0
#   }
#   departure {
#     delay: 0
#     time: 1748448660
#     uncertainty: 0
#   }
#   stop_id: "L27S"
#   schedule_relationship: SCHEDULED
# }
# stop_time_update {
#   stop_sequence: 22
#   arrival {
#     delay: 0
#     time: 1748448825
#     uncertainty: 0
#   }
#   departure {
#     delay: 0
#     time: 1748448840
#     uncertainty: 0
#   }
#   stop_id: "L28S"
#   schedule_relationship: SCHEDULED
# }
# stop_time_update {
#   stop_sequence: 23
#   arrival {
#     delay: 0
#     time: 1748448885
#     uncertainty: 0
#   }
#   stop_id: "L29S"
#   schedule_relationship: SCHEDULED
# }
# timestamp: 1748444962
# , 'vehicle': {}}
# ==========
# {'trip': trip_id: "069850_L..N"
# start_date: "20250528"
# schedule_relationship: SCHEDULED
# route_id: "L"
# direction_id: 0
# , 'trip_update': trip {
#   trip_id: "069850_L..N"
#   start_date: "20250528"
#   schedule_relationship: SCHEDULED
#   route_id: "L"
#   direction_id: 0
# }
# stop_time_update {
#   stop_sequence: 0
#   departure {
#     delay: 0
#     time: 1748446710
#     uncertainty: 0
#   }
#   stop_id: "L29N"
#   schedule_relationship: SCHEDULED
# }
# stop_time_update {
#   stop_sequence: 1
#   arrival {
#     delay: 0
#     time: 1748446785
#     uncertainty: 0
#   }
#   departure {
#     delay: 0
#     time: 1748446800
#     uncertainty: 0
#   }
#   stop_id: "L28N"
#   schedule_relationship: SCHEDULED
# }
# stop_time_update {
#   stop_sequence: 2
#   arrival {
#     delay: 0
#     time: 1748446935
#     uncertainty: 0
#   }
#   departure {
#     delay: 0
#     time: 1748446950
#     uncertainty: 0
#   }
#   stop_id: "L27N"
#   schedule_relationship: SCHEDULED
# }
# stop_time_update {
#   stop_sequence: 3
#   arrival {
#     delay: 0
#     time: 1748447025
#     uncertainty: 0
#   }
#   departure {
#     delay: 0
#     time: 1748447040
#     uncertainty: 0
#   }
#   stop_id: "L26N"
#   schedule_relationship: SCHEDULED
# }
# stop_time_update {
#   stop_sequence: 4
#   arrival {
#     delay: 0
#     time: 1748447115
#     uncertainty: 0
#   }
#   departure {
#     delay: 0
#     time: 1748447130
#     uncertainty: 0
#   }
#   stop_id: "L25N"
#   schedule_relationship: SCHEDULED
# }
# stop_time_update {
#   stop_sequence: 5
#   arrival {
#     delay: 0
#     time: 1748447205
#     uncertainty: 0
#   }
#   departure {
#     delay: 0
#     time: 1748447220
#     uncertainty: 0
#   }
#   stop_id: "L24N"
#   schedule_relationship: SCHEDULED
# }
# stop_time_update {
#   stop_sequence: 6
#   arrival {
#     delay: 0
#     time: 1748447295
#     uncertainty: 0
#   }
#   departure {
#     delay: 0
#     time: 1748447310
#     uncertainty: 0
#   }
#   stop_id: "L22N"
#   schedule_relationship: SCHEDULED
# }
# stop_time_update {
#   stop_sequence: 7
#   arrival {
#     delay: 0
#     time: 1748447355
#     uncertainty: 0
#   }
#   departure {
#     delay: 0
#     time: 1748447370
#     uncertainty: 0
#   }
#   stop_id: "L21N"
#   schedule_relationship: SCHEDULED
# }
# stop_time_update {
#   stop_sequence: 8
#   arrival {
#     delay: 0
#     time: 1748447445
#     uncertainty: 0
#   }
#   departure {
#     delay: 0
#     time: 1748447460
#     uncertainty: 0
#   }
#   stop_id: "L20N"
#   schedule_relationship: SCHEDULED
# }
# stop_time_update {
#   stop_sequence: 9
#   arrival {
#     delay: 0
#     time: 1748447595
#     uncertainty: 0
#   }
#   departure {
#     delay: 0
#     time: 1748447610
#     uncertainty: 0
#   }
#   stop_id: "L19N"
#   schedule_relationship: SCHEDULED
# }
# stop_time_update {
#   stop_sequence: 10
#   arrival {
#     delay: 0
#     time: 1748447685
#     uncertainty: 0
#   }
#   departure {
#     delay: 0
#     time: 1748447700
#     uncertainty: 0
#   }
#   stop_id: "L17N"
#   schedule_relationship: SCHEDULED
# }
# stop_time_update {
#   stop_sequence: 11
#   arrival {
#     delay: 0
#     time: 1748447775
#     uncertainty: 0
#   }
#   departure {
#     delay: 0
#     time: 1748447790
#     uncertainty: 0
#   }
#   stop_id: "L16N"
#   schedule_relationship: SCHEDULED
# }
# stop_time_update {
#   stop_sequence: 12
#   arrival {
#     delay: 0
#     time: 1748447865
#     uncertainty: 0
#   }
#   departure {
#     delay: 0
#     time: 1748447880
#     uncertainty: 0
#   }
#   stop_id: "L15N"
#   schedule_relationship: SCHEDULED
# }
# stop_time_update {
#   stop_sequence: 13
#   arrival {
#     delay: 0
#     time: 1748447985
#     uncertainty: 0
#   }
#   departure {
#     delay: 0
#     time: 1748448000
#     uncertainty: 0
#   }
#   stop_id: "L14N"
#   schedule_relationship: SCHEDULED
# }
# stop_time_update {
#   stop_sequence: 14
#   arrival {
#     delay: 0
#     time: 1748448075
#     uncertainty: 0
#   }
#   departure {
#     delay: 0
#     time: 1748448090
#     uncertainty: 0
#   }
#   stop_id: "L13N"
#   schedule_relationship: SCHEDULED
# }
# stop_time_update {
#   stop_sequence: 15
#   arrival {
#     delay: 0
#     time: 1748448135
#     uncertainty: 0
#   }
#   departure {
#     delay: 0
#     time: 1748448150
#     uncertainty: 0
#   }
#   stop_id: "L12N"
#   schedule_relationship: SCHEDULED
# }
# stop_time_update {
#   stop_sequence: 16
#   arrival {
#     delay: 0
#     time: 1748448225
#     uncertainty: 0
#   }
#   departure {
#     delay: 0
#     time: 1748448240
#     uncertainty: 0
#   }
#   stop_id: "L11N"
#   schedule_relationship: SCHEDULED
# }
# stop_time_update {
#   stop_sequence: 17
#   arrival {
#     delay: 0
#     time: 1748448285
#     uncertainty: 0
#   }
#   departure {
#     delay: 0
#     time: 1748448300
#     uncertainty: 0
#   }
#   stop_id: "L10N"
#   schedule_relationship: SCHEDULED
# }
# stop_time_update {
#   stop_sequence: 18
#   arrival {
#     delay: 0
#     time: 1748448375
#     uncertainty: 0
#   }
#   departure {
#     delay: 0
#     time: 1748448390
#     uncertainty: 0
#   }
#   stop_id: "L08N"
#   schedule_relationship: SCHEDULED
# }
# stop_time_update {
#   stop_sequence: 19
#   arrival {
#     delay: 0
#     time: 1748448585
#     uncertainty: 0
#   }
#   departure {
#     delay: 0
#     time: 1748448600
#     uncertainty: 0
#   }
#   stop_id: "L06N"
#   schedule_relationship: SCHEDULED
# }
# stop_time_update {
#   stop_sequence: 20
#   arrival {
#     delay: 0
#     time: 1748448645
#     uncertainty: 0
#   }
#   departure {
#     delay: 0
#     time: 1748448660
#     uncertainty: 0
#   }
#   stop_id: "L05N"
#   schedule_relationship: SCHEDULED
# }
# stop_time_update {
#   stop_sequence: 21
#   arrival {
#     delay: 0
#     time: 1748448705
#     uncertainty: 0
#   }
#   departure {
#     delay: 0
#     time: 1748448720
#     uncertainty: 0
#   }
#   stop_id: "L03N"
#   schedule_relationship: SCHEDULED
# }
# stop_time_update {
#   stop_sequence: 22
#   arrival {
#     delay: 0
#     time: 1748448795
#     uncertainty: 0
#   }
#   departure {
#     delay: 0
#     time: 1748448810
#     uncertainty: 0
#   }
#   stop_id: "L02N"
#   schedule_relationship: SCHEDULED
# }
# stop_time_update {
#   stop_sequence: 23
#   arrival {
#     delay: 0
#     time: 1748448945
#     uncertainty: 0
#   }
#   stop_id: "L01N"
#   schedule_relationship: SCHEDULED
# }
# timestamp: 1748444962
# , 'vehicle': {}}
# ==========

# %% [markdown]
# Stop time updates work differently than I actually thought. Rather than storing
# old information, they store the stop times for *all* future stops. This is
# great, but still presents some challenges. We need to get the previous stop and its time.

# %%
pos = 0
ct = 0
for obj in dict(updates).values():
    ct += 1
    ts = obj['trip_update'].timestamp

    for stu in obj['trip_update'].stop_time_update:
        #print(stu)
        if (stu.arrival.time < ts):
            #print("Passed stop")
            pos += 1
            break
        #print('='*10)

    

print(pos, ct)
# Out:
# 17 32
